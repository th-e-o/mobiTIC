# %%
import sys
from pathlib import Path

# Obtenir la racine du projet
PROJECT_ROOT = Path.cwd()  

# Ajouter le dossier src au PYTHONPATH
SRC_DIR = PROJECT_ROOT / "src"
sys.path.insert(0, str(SRC_DIR))

from utils.data_manager import iris_loader, bpe_loader

# %% [markdown]
# Preview of the sources

# %%
iris_gdf, bpe_gdf = iris_loader(), bpe_loader()

# %%
iris_gdf.head()
# Out:
#                      cleabs  ...                                           geometry
# 0  IRIS____0000000693860101  ...  MULTIPOLYGON (((4.84291 45.77854, 4.84306 45.7...
# 1  IRIS____0000000692710101  ...  MULTIPOLYGON (((4.97819 45.73147, 4.9777 45.72...
# 2  IRIS____0000000693830101  ...  MULTIPOLYGON (((4.8421 45.76137, 4.84428 45.76...
# 3  IRIS____0000000692590101  ...  MULTIPOLYGON (((4.86514 45.70781, 4.86404 45.7...
# 4  IRIS____0000000690270101  ...  MULTIPOLYGON (((4.77987 45.67589, 4.77983 45.6...
#
# [5 rows x 9 columns]

# %%
bpe_gdf.head()
