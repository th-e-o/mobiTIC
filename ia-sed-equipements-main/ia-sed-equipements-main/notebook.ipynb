# %%
import sys
from pathlib import Path

# Obtenir la racine du projet
# PROJECT_ROOT = Path.cwd()  

# Ajouter le dossier src au PYTHONPATH
# SRC_DIR = PROJECT_ROOT / "src"
# sys.path.insert(0, str(SRC_DIR))
from utils.data_manager import iris_loader, bpe_loader
from config.settings import PATH_DATA_30min_Nuitee, PATH_DATA_30min, IRIS_PATH
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[26], line 10
#       2 from pathlib import Path
#       4 # Obtenir la racine du projet
#       5 # PROJECT_ROOT = Path.cwd()
#       6
#       7 # Ajouter le dossier src au PYTHONPATH
#       8 # SRC_DIR = PROJECT_ROOT / "src"
#       9 # sys.path.insert(0, str(SRC_DIR))
# ---> 10 from utils.data_manager import iris_loader, bpe_loader
#      11 from config.settings import PATH_DATA_30min_Nuitee, PATH_DATA_30min, IRIS_PATH
#
# File ~/work/ia-sed-equipements/src/utils/data_manager.py:2
#       1 import logging
# ----> 2 import geopandas as gpd
#       4 from config.settings import IRIS_PATH, BPE_GEO_PATH
#       5 from config.categories import get_category
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
print("Python du kernel:", sys.executable)
print("\nSys.path:")
for p in sys.path:
    print(f"  {p}")
# Out:
# Python du kernel: /home/onyxia/work/.venv/bin/python
#
# Sys.path:
#   /home/onyxia/work/ia-sed-equipements/src
#   /home/onyxia/work/ia-sed-equipements/src
#   /home/onyxia/work/ia-sed-equipements/src
#   /home/onyxia/work/ia-sed-equipements/src
#   /home/onyxia/work/ia-sed-equipements/src
#   /opt/python/lib/python313.zip
#   /opt/python/lib/python3.13
#   /opt/python/lib/python3.13/lib-dynload
#
#   /home/onyxia/work/.venv/lib/python3.13/site-packages

# %%
# !source /home/onyxia/work/ia-sed-equipements/.venv/bin/activate

# %%
PATH_DATA_30min
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 PATH_DATA_30min
#
# NameError: name 'PATH_DATA_30min' is not defined

# %%
import polars as pl

file_path = PATH_DATA_30min / 'Date=2022-09-05' / 'part-0.parquet'
print(file_path)
# Lire le fichier
df = pl.read_parquet(file_path)

# Voir les premières lignes
df.head()
# Out:
# /home/onyxia/work/ia-sed-equipements/data/bdd_data_presence/Presence30min/Date=2022-09-05/part-0.parquet
# shape: (5, 4)
# ┌─────────────┬───────────┬──────────┬────────┐
# │ Heure       ┆ Zone      ┆ Type     ┆ Volume │
# │ ---         ┆ ---       ┆ ---      ┆ ---    │
# │ str         ┆ str       ┆ str      ┆ f64    │
# ╞═════════════╪═══════════╪══════════╪════════╡
# │ 00:00-00:30 ┆ 010010000 ┆ National ┆ 392.0  │
# │ 00:00-00:30 ┆ 010020000 ┆ National ┆ 113.0  │
# │ 00:00-00:30 ┆ 010040101 ┆ Etranger ┆ 235.0  │
# │ 00:00-00:30 ┆ 010040101 ┆ National ┆ 3835.0 │
# │ 00:00-00:30 ┆ 010040102 ┆ Etranger ┆ 95.0   │
# └─────────────┴───────────┴──────────┴────────┘

# %%
get_available_dates()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 get_available_dates()
#
# NameError: name 'get_available_dates' is not defined
